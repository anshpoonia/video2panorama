# %%
import numpy as np
import tensorflow as tf
import cv2 as cv
import math
import threading
from scipy.optimize import least_squares
# Out:
# C:\Users\pooni\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\__init__.py:78: RequestsDependencyWarning: urllib3 (1.26.15) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({0}) or chardet ({1}) doesn't match a supported "
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [1], line 2
#       1 import numpy as np
# ----> 2 import tensorflow as tf
#       3 import cv2 as cv
#       4 import math
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\__init__.py:37
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\__init__.py:45
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
# ---> 45 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      46 # from tensorflow.python.layers import layers
#      47 from tensorflow.python.module import module
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\feature_column\feature_column_lib.py:18
#      15 """FeatureColumns: tools for ingesting and representing features."""
#      17 # pylint: disable=unused-import,line-too-long,wildcard-import,g-bad-import-order
# ---> 18 from tensorflow.python.feature_column.feature_column import *
#      19 from tensorflow.python.feature_column.feature_column_v2 import *
#      20 from tensorflow.python.feature_column.sequence_feature_column import *
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\feature_column\feature_column.py:143
#     141 from tensorflow.python.framework import sparse_tensor as sparse_tensor_lib
#     142 from tensorflow.python.framework import tensor_shape
# --> 143 from tensorflow.python.layers import base
#     144 from tensorflow.python.ops import array_ops
#     145 from tensorflow.python.ops import check_ops
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\layers\base.py:16
#       1 # Copyright 2015 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # =============================================================================
#      15 """Contains the base Layer class, from which all layers inherit."""
# ---> 16 from tensorflow.python.keras.legacy_tf_layers import base
#      18 InputSpec = base.InputSpec
#      20 keras_style_scope = base.keras_style_scope
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\keras\__init__.py:25
#      22 from tensorflow.python.keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from tensorflow.python.keras import models
#      27 from tensorflow.python.keras.engine.input_layer import Input
#      28 from tensorflow.python.keras.engine.sequential import Sequential
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\keras\models.py:22
#      20 from tensorflow.python.keras import metrics as metrics_module
#      21 from tensorflow.python.keras import optimizer_v1
# ---> 22 from tensorflow.python.keras.engine import functional
#      23 from tensorflow.python.keras.engine import sequential
#      24 from tensorflow.python.keras.engine import training
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\keras\engine\functional.py:32
#      30 from tensorflow.python.keras.engine import input_spec
#      31 from tensorflow.python.keras.engine import node as node_module
# ---> 32 from tensorflow.python.keras.engine import training as training_lib
#      33 from tensorflow.python.keras.engine import training_utils
#      34 from tensorflow.python.keras.saving.saved_model import network_serialization
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\keras\engine\training.py:44
#      42 from tensorflow.python.framework import tensor_shape
#      43 from tensorflow.python.keras import backend
# ---> 44 from tensorflow.python.keras import callbacks as callbacks_module
#      45 from tensorflow.python.keras import optimizer_v1
#      46 from tensorflow.python.keras import optimizers
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\keras\callbacks.py:68
#      65 from tensorflow.tools.docs import doc_controls
#      67 try:
# ---> 68   import requests
#      69 except ImportError:
#      70   requests = None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\__init__.py:97
#      94 from .__version__ import __build__, __author__, __author_email__, __license__
#      95 from .__version__ import __copyright__, __cake__
# ---> 97 from . import utils
#      98 from . import packages
#      99 from .models import Request, Response, PreparedRequest
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\utils.py:32
#      27 from .compat import parse_http_list as _parse_list_header
#      28 from .compat import (
#      29     quote, urlparse, bytes, str, OrderedDict, unquote, getproxies,
#      30     proxy_bypass, urlunparse, basestring, integer_types, is_py3,
#      31     proxy_bypass_environment, getproxies_environment)
# ---> 32 from .cookies import cookiejar_from_dict
#      33 from .structures import CaseInsensitiveDict
#      34 from .exceptions import (
#      35     InvalidURL, InvalidHeader, FileModeWarning, UnrewindableBodyError)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\cookies.py:172
#     166 class CookieConflictError(RuntimeError):
#     167     """There are two cookies that meet the criteria specified in the cookie jar.
#     168     Use .get and .set and include domain and path args in order to be more specific.
#     169     """
# --> 172 class RequestsCookieJar(cookielib.CookieJar, collections.MutableMapping):
#     173     """Compatibility class; is a cookielib.CookieJar, but exposes a dict
#     174     interface.
#     175
#    (...)
#     187     .. warning:: dictionary operations that are normally O(1) may be O(n).
#     188     """
#     190     def get(self, name, default=None, domain=None, path=None):
#
# AttributeError: module 'collections' has no attribute 'MutableMapping'

# %%
LAYERS = [
    ('Conv1',1),
    ('block_1_project',1),
    ('block_2_project',1),
    ('block_3_project',1),
    ('block_4_project',1),
    ('block_5_project',1),
    ('block_6_project',1),
    ('block_7_project',1),
    ('block_8_project',1),
    ('block_9_project',1),
    ('block_10_project',1),
    ('block_11_project',1),
    ('block_12_project',1),
    ('block_13_project',1),
    ('block_14_project',1),
    ('block_15_project',1),
    ('block_16_project',1),
    ('Conv_1', 1)
]

def content_error(content_image_output, generated_image_output):
    m, nh, nw, nc = content_image_output.get_shape().as_list()

    ac = tf.reshape(content_image_output, shape=[m, -1, nc])
    ag = tf.reshape(generated_image_output, shape=[m, -1, nc])

    j_content = tf.divide(tf.reduce_sum(tf.square(tf.subtract(ac, ag))), (4.0 * nh * nw * nc))

    return j_content

def construct_model(size, layers=LAYERS):
    temp = tf.keras.applications.MobileNetV2(include_top=False,
                                       input_shape=size + (3,),
                                       weights='imagenet')
    temp.trainable = False
    output = [temp.get_layer(layer[0]).output for layer in layers]
    temp_model = tf.keras.Model([temp.input], output)
    return temp_model

def find_params(model, image):
    image = cv.resize(image, (224, 224))
    image = np.array([image])

    params = model(image)

    return params

def find_feature_loss(params_one, params_two):
    feature_loss = []
    for i,j in zip(params_one,params_two):
        feature_loss.append(content_error(i, j))
    feature_loss = np.array(feature_loss)
    res = np.prod(feature_loss)
    return res

# %%
def find_quality(image):
    my_kernel = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
    image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
    image = cv.filter2D(image, -1, cv.flip(my_kernel, -1), borderType=cv.BORDER_CONSTANT)
    res = np.std(image)
    return res

# %%
def make_mask(first_image, second_image, flag):
    height = second_image.shape[0]
    width = second_image.shape[1]
    window = 200
    offset = first_image.shape[1] - window
    mask = np.zeros((height, width))

    if flag == 'l':
        mask[:, offset-window:offset+window] = np.tile( np.linspace(1, 0, 2*window).T, (height, 1))
        mask[:, :offset-window] = 1
    elif flag == 'r':
        mask[:, offset-window:offset+window] = np.tile( np.linspace(0, 1, 2*window).T, (height, 1))
        mask[:, offset+window:] = 1
    return cv.merge([mask, mask, mask])

def overlap(first_image, result_image):
    height = first_image.shape[0]
    width = first_image.shape[1]
    left_mask = make_mask(first_image, result_image, 'l')
    right_mask = make_mask(first_image, result_image, 'r')

    result_zero = result_image[:, :] != [0,0,0]
    first_zero = first_image[:, :] != [0,0,0]

    left_mask = left_mask * result_zero
    right_mask[0:height, 0:width] = right_mask[0:height, 0:width] * first_zero

    left_mask = left_mask + ~result_zero
    right_mask[0:height, 0:width] = right_mask[0:height, 0:width] + ~first_zero

    result_image = result_image * right_mask
    first_image = first_image * left_mask[0:height, 0:width]

    result_image[0:height, 0:width] = result_image[0:height, 0:width] + first_image


    return result_image

# %%
def resize(image, resolution):
    height = image.shape[0]
    width = image.shape[1]

    if height > resolution:
        n = height / resolution
        image = cv.resize(image, (int(width / n), resolution))

    return image

def loss(h, base_pts, res_pts):
    h = h.reshape(3,3)
    res1 = cv.perspectiveTransform(res_pts.reshape(-1,1,2), h).reshape(-1,2)

    h_inv = np.linalg.inv(h)
    res2 = cv.perspectiveTransform(base_pts.reshape(-1, 1, 2), h_inv).reshape(-1, 2)

    return ((base_pts - res1) + (res_pts - res2)).flatten()

# def loss(h, base_pts, res_pts):
#     h = h.reshape(3,3)
#     res1 = cv.perspectiveTransform(res_pts.reshape(-1,1,2), h).reshape(-1,2)
#
#     h_inv = np.linalg.inv(h)
#     res2 = cv.perspectiveTransform(base_pts.reshape(-1, 1, 2), h_inv).reshape(-1, 2)
#
#     return ((np.power((np.power((base_pts[:, 0], res1[:, 0]), 2) + np.power((base_pts[:, 1], res1[:, 1]), 2)), 0.5)) + (np.power((np.power((res_pts[:, 0], res2[:, 0]), 2) + np.power((res_pts[:, 1], res2[:, 1]), 2)), 0.5))).flatten()

class JoinOne:
    def find_keypoint(self, image):
        image_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
        sift = cv.SIFT_create()
        (key_point, feature) = sift.detectAndCompute(image_gray, None)
        key_point = np.float32([k.pt for k in key_point])
        return key_point, feature

    def find_homography(self, train_key_point, query_key_point, train_feature, query_feature, ratio, threshold):
        matcher = cv.BFMatcher()
        match_points = matcher.knnMatch(train_feature, query_feature, k=2)
        valid_match_points = []

        for m in match_points:
            if m[0].distance < m[1].distance * ratio:
                valid_match_points.append((m[0].trainIdx, m[0].queryIdx))
        if len(valid_match_points) > 4:
            train_valid_points = np.float32([train_key_point[i] for (_, i) in valid_match_points])
            query_valid_points = np.float32([query_key_point[i] for (i, _) in valid_match_points])

            (H, status) = cv.findHomography(train_valid_points, query_valid_points, cv.RANSAC, threshold)
            res_h = least_squares(loss, H.flatten(), args=(query_valid_points, train_valid_points), method='lm')
            H = res_h.x.reshape(3,3)

        return valid_match_points, H, status

    def stitch_images(self, train_image, query_image, ratio=0.7, threshold=4.0):
        resolution = 3840

        train_image = resize(train_image, resolution)
        query_image = resize(query_image, resolution)

        image_one = train_image
        image_two = query_image

        # image_two_width = image_two.shape[1]
        # image_two_height - image_two.shape[0]
        #
        # divide = int((3*image_two_width)/5)

        # image_two_first_section = image_two[:, 0:divide]
        # image_two_second_section = image_two[:, divide:image_two_width]



        (train_key_point, train_feature) = self.find_keypoint(train_image)
        (query_key_point, query_feature) = self.find_keypoint(query_image)

        (valid_match_points, H, status) = self.find_homography(train_key_point, query_key_point, train_feature, query_feature, ratio, threshold)

        width = image_one.shape[1] + image_two.shape[1]
        height = image_two.shape[0]

        result_image = cv.warpPerspective( image_one, H, (width, height))
        result_image = overlap(image_two, result_image)

        rows, cols = np.where(result_image[:, :, 0] != 0)
        min_row, max_row = min(rows), max(rows) + 1
        min_col, max_col = min(cols), max(cols) + 1
        final_result = result_image[min_row:max_row, min_col:max_col, :]

        return final_result

# %%
# instantaneous variables
params = None
frame = None
quality = None
panorama = []
current_best = 0
count = 0

model = construct_model((224, 224))


# function to join image
def joinImages():
    global panorama, current_best, count
    print("<<<<<----- Joining images ----->>>>>")
    panorama = JoinOne().stitch_images(current_best[0], panorama)
    panorama = cv.normalize(panorama, None, 0, 255, cv.NORM_MINMAX).astype('uint8')
    cv.imwrite(f'intermediate_results/b {count}.jpg', panorama)
    print("<<<<<----- Joining complete ----->>>>>")

# function to find params
def run_find_params():
    global params, frame, model, count
    print(f"<< finding params for: {count} >>")
    params = find_params(model, frame)
    return params

# function to find quality
def run_find_quality():
    global  quality, frame, count
    print(f"<< finding quality for: {count} >>")
    quality = find_quality(frame)
    return quality


def make_panorama(video_name):
    global params, frame, quality, panorama, current_best, count
    # static values
    threshold = 2

    # similarity model

    # main variables

    base_params = 0


    video = cv.VideoCapture(video_name)

    # thread to join images
    join_image = None



    while video.isOpened():

        # instantaneous variables
        params = None
        quality = None

        count += 1
        ret, frame = video.read()

        if not ret:
            join_image.join()
            join_image = threading.Thread(target=joinImages)
            join_image.start()
            break

        frame = cv.rotate(frame, cv.ROTATE_180)

        print(f"<< finding stats for : {count} >>")

        # thread to find params
        find_p = threading.Thread(target=run_find_params)

        # thread to find quality
        find_q = threading.Thread(target=run_find_quality)

        find_p.start()
        find_q.start()

        find_p.join()
        find_q.join()


        if base_params != 0:
            feature_loss = find_feature_loss(params, base_params)

            if feature_loss * math.pow(10,23)  < threshold:

                if quality > current_best[1]:
                    current_best = [frame, quality]
            else:
                if len(panorama) != 0:
                    if join_image is not None: join_image.join()
                    join_image = threading.Thread(target=joinImages)
                    join_image.start()

                else:
                    panorama = current_best[0]
                base_params = params
                current_best = [frame, quality]


        else:
            base_params = params
            current_best = [frame, quality]

        print(f"Completed frame: {count}")
        print("-------------------------")

    video.release()
    join_image.join()
    return panorama

# %%
res = make_panorama("E:/Ansh Poonia/Desktop/computer vision/video/12.mp4")
# Out:
# << finding stats for : 1 >>
# << finding params for: 1 >>
# << finding quality for: 1 >>
# Completed frame: 1
# -------------------------
# << finding stats for : 2 >>
# << finding params for: 2 >>
# << finding quality for: 2 >>
# Completed frame: 2
# -------------------------
# << finding stats for : 3 >>
# << finding params for: 3 >>
# << finding quality for: 3 >>
# Completed frame: 3
# -------------------------
# << finding stats for : 4 >>
# << finding params for: 4 >>
# << finding quality for: 4 >>
# Completed frame: 4
# -------------------------
# << finding stats for : 5 >>
# << finding params for: 5 >>
# << finding quality for: 5 >>
# Completed frame: 5
# -------------------------
# << finding stats for : 6 >>
# << finding params for: 6 >>
# << finding quality for: 6 >>
# Completed frame: 6
# -------------------------
# << finding stats for : 7 >>
# << finding params for: 7 >>
# << finding quality for: 7 >>
# Completed frame: 7
# -------------------------
# << finding stats for : 8 >>
# << finding params for: 8 >>
# << finding quality for: 8 >>
# Completed frame: 8
# -------------------------
# << finding stats for : 9 >>
# << finding params for: 9 >>
# << finding quality for: 9 >>
# Completed frame: 9
# -------------------------
# << finding stats for : 10 >>
# << finding params for: 10 >>
# << finding quality for: 10 >>
# Completed frame: 10
# -------------------------
# << finding stats for : 11 >>
# << finding params for: 11 >>
# << finding quality for: 11 >>
# Completed frame: 11
# -------------------------
# << finding stats for : 12 >>
# << finding params for: 12 >>
# << finding quality for: 12 >>
# Completed frame: 12
# -------------------------
# << finding stats for : 13 >>
# << finding params for: 13 >>
# << finding quality for: 13 >>
# Completed frame: 13
# -------------------------
# << finding stats for : 14 >>
# << finding params for: 14 >>
# << finding quality for: 14 >>
# Completed frame: 14
# -------------------------
# << finding stats for : 15 >>
# << finding params for: 15 >>
# << finding quality for: 15 >>
# Completed frame: 15
# -------------------------
# << finding stats for : 16 >>
# << finding params for: 16 >>
# << finding quality for: 16 >>
# Completed frame: 16
# -------------------------
# << finding stats for : 17 >>
# << finding params for: 17 >>
# << finding quality for: 17 >>
# Completed frame: 17
# -------------------------
# << finding stats for : 18 >>
# << finding params for: 18 >>
# << finding quality for: 18 >>
# Completed frame: 18
# -------------------------
# << finding stats for : 19 >>
# << finding params for: 19 >>
# << finding quality for: 19 >>
# Completed frame: 19
# -------------------------
# << finding stats for : 20 >>
# << finding params for: 20 >>
# << finding quality for: 20 >>
# Completed frame: 20
# -------------------------
# << finding stats for : 21 >>
# << finding params for: 21 >>
# << finding quality for: 21 >>
# Completed frame: 21
# -------------------------
# << finding stats for : 22 >>
# << finding params for: 22 >>
# << finding quality for: 22 >>
# Completed frame: 22
# -------------------------
# << finding stats for : 23 >>
# << finding params for: 23 >>
# << finding quality for: 23 >>
# Completed frame: 23
# -------------------------
# << finding stats for : 24 >>
# << finding params for: 24 >>
# << finding quality for: 24 >>
# Completed frame: 24
# -------------------------
# << finding stats for : 25 >>
# << finding params for: 25 >>
# << finding quality for: 25 >>
# Completed frame: 25
# -------------------------
# << finding stats for : 26 >>
# << finding params for: 26 >>
# << finding quality for: 26 >>
# Completed frame: 26
# -------------------------
# << finding stats for : 27 >>
# << finding params for: 27 >>
# << finding quality for: 27 >>
# Completed frame: 27
# -------------------------
# << finding stats for : 28 >>
# << finding params for: 28 >>
# << finding quality for: 28 >>
# Completed frame: 28
# -------------------------
# << finding stats for : 29 >>
# << finding params for: 29 >>
# << finding quality for: 29 >>
# Completed frame: 29
# -------------------------
# << finding stats for : 30 >>
# << finding params for: 30 >>
# << finding quality for: 30 >>
# Completed frame: 30
# -------------------------
# << finding stats for : 31 >>
# << finding params for: 31 >>
# << finding quality for: 31 >>
# Completed frame: 31
# -------------------------
# << finding stats for : 32 >>
# << finding params for: 32 >>
# << finding quality for: 32 >>
# Completed frame: 32
# -------------------------
# << finding stats for : 33 >>
# << finding params for: 33 >>
# << finding quality for: 33 >>
# Completed frame: 33
# -------------------------
# << finding stats for : 34 >>
# << finding params for: 34 >>
# << finding quality for: 34 >>
# Completed frame: 34
# -------------------------
# << finding stats for : 35 >>
# << finding params for: 35 >>
# << finding quality for: 35 >>
# Completed frame: 35
# -------------------------
# << finding stats for : 36 >>
# << finding params for: 36 >>
# << finding quality for: 36 >>
# Completed frame: 36
# -------------------------
# << finding stats for : 37 >>
# << finding params for: 37 >>
# << finding quality for: 37 >>
# Completed frame: 37
# -------------------------
# << finding stats for : 38 >>
# << finding params for: 38 >>
# << finding quality for: 38 >>
# Completed frame: 38
# -------------------------
# << finding stats for : 39 >>
# << finding params for: 39 >>
# << finding quality for: 39 >>
# Completed frame: 39
# -------------------------
# << finding stats for : 40 >>
# << finding params for: 40 >>
# << finding quality for: 40 >>
# Completed frame: 40
# -------------------------
# << finding stats for : 41 >>
# << finding params for: 41 >>
# << finding quality for: 41 >>
# Completed frame: 41
# -------------------------
# << finding stats for : 42 >>
# << finding params for: 42 >>
# << finding quality for: 42 >>
# Completed frame: 42
# -------------------------
# << finding stats for : 43 >>
# << finding params for: 43 >>
# << finding quality for: 43 >>
# Completed frame: 43
# -------------------------
# << finding stats for : 44 >>
# << finding params for: 44 >>
# << finding quality for: 44 >>
# Completed frame: 44
# -------------------------
# << finding stats for : 45 >>
# << finding params for: 45 >>
# << finding quality for: 45 >>
# Completed frame: 45
# -------------------------
# << finding stats for : 46 >>
# << finding params for: 46 >>
# << finding quality for: 46 >>
# Completed frame: 46
# -------------------------
# << finding stats for : 47 >>
# << finding params for: 47 >>
# << finding quality for: 47 >>
# Completed frame: 47
# -------------------------
# << finding stats for : 48 >>
# << finding params for: 48 >>
# << finding quality for: 48 >>
# Completed frame: 48
# -------------------------
# << finding stats for : 49 >>
# << finding params for: 49 >>
# << finding quality for: 49 >>
# Completed frame: 49
# -------------------------
# << finding stats for : 50 >>
# << finding params for: 50 >>
# << finding quality for: 50 >>
# Completed frame: 50
# -------------------------
# << finding stats for : 51 >>
# << finding params for: 51 >>
# << finding quality for: 51 >>
# Completed frame: 51
# -------------------------
# << finding stats for : 52 >>
# << finding params for: 52 >>
# << finding quality for: 52 >>
# Completed frame: 52
# -------------------------
# << finding stats for : 53 >>
# << finding params for: 53 >>
# << finding quality for: 53 >>
# Completed frame: 53
# -------------------------
# << finding stats for : 54 >>
# << finding params for: 54 >>
# << finding quality for: 54 >>
# Completed frame: 54
# -------------------------
# << finding stats for : 55 >>
# << finding params for: 55 >>
# << finding quality for: 55 >>
# Completed frame: 55
# -------------------------
# << finding stats for : 56 >>
# << finding params for: 56 >>
# << finding quality for: 56 >>
# Completed frame: 56
# -------------------------
# << finding stats for : 57 >>
# << finding params for: 57 >>
# << finding quality for: 57 >>
# Completed frame: 57
# -------------------------
# << finding stats for : 58 >>
# << finding params for: 58 >>
# << finding quality for: 58 >>
# Completed frame: 58
# -------------------------
# << finding stats for : 59 >>
# << finding params for: 59 >>
# << finding quality for: 59 >>
# Completed frame: 59
# -------------------------
# << finding stats for : 60 >>
# << finding params for: 60 >>
# << finding quality for: 60 >>
# Completed frame: 60
# -------------------------
# << finding stats for : 61 >>
# << finding params for: 61 >>
# << finding quality for: 61 >>
# Completed frame: 61
# -------------------------
# << finding stats for : 62 >>
# << finding params for: 62 >>
# << finding quality for: 62 >>
# Completed frame: 62
# -------------------------
# << finding stats for : 63 >>
# << finding params for: 63 >>
# << finding quality for: 63 >>
# Completed frame: 63
# -------------------------
# << finding stats for : 64 >>
# << finding params for: 64 >>
# << finding quality for: 64 >>
# Completed frame: 64
# -------------------------
# << finding stats for : 65 >>
# << finding params for: 65 >>
# << finding quality for: 65 >>
# Completed frame: 65
# -------------------------
# << finding stats for : 66 >>
# << finding params for: 66 >>
# << finding quality for: 66 >>
# Completed frame: 66
# -------------------------
# << finding stats for : 67 >>
# << finding params for: 67 >>
# << finding quality for: 67 >>
# Completed frame: 67
# -------------------------
# << finding stats for : 68 >>
# << finding params for: 68 >>
# << finding quality for: 68 >>
# Completed frame: 68
# -------------------------
# << finding stats for : 69 >>
# << finding params for: 69 >>
# << finding quality for: 69 >>
# Completed frame: 69
# -------------------------
# << finding stats for : 70 >>
# << finding params for: 70 >>
# << finding quality for: 70 >>
# Completed frame: 70
# -------------------------
# << finding stats for : 71 >>
# << finding params for: 71 >>
# << finding quality for: 71 >>
# Completed frame: 71
# -------------------------
# << finding stats for : 72 >>
# << finding params for: 72 >>
# << finding quality for: 72 >>
# Completed frame: 72
# -------------------------
# << finding stats for : 73 >>
# << finding params for: 73 >>
# << finding quality for: 73 >>
# Completed frame: 73
# -------------------------
# << finding stats for : 74 >>
# << finding params for: 74 >>
# << finding quality for: 74 >>
# Completed frame: 74
# -------------------------
# << finding stats for : 75 >>
# << finding params for: 75 >>
# << finding quality for: 75 >>
# Completed frame: 75
# -------------------------
# << finding stats for : 76 >>
# << finding params for: 76 >>
# << finding quality for: 76 >>
# <<<<<----- Joining images ----->>>>>
# Completed frame: 76
# -------------------------
# << finding stats for : 77 >>
# << finding params for: 77 >>
# << finding quality for: 77 >>
# Completed frame: 77
# -------------------------
# << finding stats for : 78 >>
# << finding params for: 78 >>
# << finding quality for: 78 >>
# Completed frame: 78
# -------------------------
# << finding stats for : 79 >>
# << finding params for: 79 >>
# << finding quality for: 79 >>
# Completed frame: 79
# -------------------------
# << finding stats for : 80 >>
# << finding params for: 80 >>
# << finding quality for: 80 >>
# Completed frame: 80
# -------------------------
# << finding stats for : 81 >>
# << finding params for: 81 >>
# << finding quality for: 81 >>
# Completed frame: 81
# -------------------------
# << finding stats for : 82 >>
# << finding params for: 82 >>
# << finding quality for: 82 >>
# Completed frame: 82
# -------------------------
# << finding stats for : 83 >>
# << finding params for: 83 >>
# << finding quality for: 83 >>
# Completed frame: 83
# -------------------------
# << finding stats for : 84 >>
# << finding params for: 84 >>
# << finding quality for: 84 >>
# Completed frame: 84
# -------------------------
# << finding stats for : 85 >>
# << finding params for: 85 >>
# << finding quality for: 85 >>
# Completed frame: 85
# -------------------------
# << finding stats for : 86 >>
# << finding params for: 86 >>
# << finding quality for: 86 >>
# Completed frame: 86
# -------------------------
# << finding stats for : 87 >>
# << finding params for: 87 >>
# << finding quality for: 87 >>
# Completed frame: 87
# -------------------------
# << finding stats for : 88 >>
# << finding params for: 88 >>
# << finding quality for: 88 >>
# Completed frame: 88
# -------------------------
# << finding stats for : 89 >>
# << finding params for: 89 >>
# << finding quality for: 89 >>
# Completed frame: 89
# -------------------------
# << finding stats for : 90 >>
# << finding params for: 90 >>
# << finding quality for: 90 >>
# Completed frame: 90
# -------------------------
# << finding stats for : 91 >>
# << finding params for: 91 >>
# << finding quality for: 91 >>
# Completed frame: 91
# -------------------------
# << finding stats for : 92 >>
# << finding params for: 92 >>
# << finding quality for: 92 >>
# Completed frame: 92
# -------------------------
# << finding stats for : 93 >>
# << finding params for: 93 >>
# << finding quality for: 93 >>
# Completed frame: 93
# -------------------------
# << finding stats for : 94 >>
# << finding params for: 94 >>
# << finding quality for: 94 >>
# Completed frame: 94
# -------------------------
# << finding stats for : 95 >>
# << finding params for: 95 >>
# << finding quality for: 95 >>
# Completed frame: 95
# -------------------------
# << finding stats for : 96 >>
# << finding params for: 96 >>
# << finding quality for: 96 >>
# Completed frame: 96
# -------------------------
# << finding stats for : 97 >>
# << finding params for: 97 >>
# << finding quality for: 97 >>
# Completed frame: 97
# -------------------------
# << finding stats for : 98 >>
# << finding params for: 98 >>
# << finding quality for: 98 >>
# Completed frame: 98
# -------------------------
# << finding stats for : 99 >>
# << finding params for: 99 >>
# << finding quality for: 99 >>
# <<<<<----- Joining complete ----->>>>>
# <<<<<----- Joining images ----->>>>>
# Completed frame: 99
# -------------------------
# << finding stats for : 100 >>
# << finding params for: 100 >>
# << finding quality for: 100 >>
# Completed frame: 100
# -------------------------
# << finding stats for : 101 >>
# << finding params for: 101 >>
# << finding quality for: 101 >>
# Completed frame: 101
# -------------------------
# << finding stats for : 102 >>
# << finding params for: 102 >>
# << finding quality for: 102 >>
# Completed frame: 102
# -------------------------
# << finding stats for : 103 >>
# << finding params for: 103 >>
# << finding quality for: 103 >>
# Completed frame: 103
# -------------------------
# << finding stats for : 104 >>
# << finding params for: 104 >>
# << finding quality for: 104 >>
# Completed frame: 104
# -------------------------
# << finding stats for : 105 >>
# << finding params for: 105 >>
# << finding quality for: 105 >>
# Completed frame: 105
# -------------------------
# << finding stats for : 106 >>
# << finding params for: 106 >>
# << finding quality for: 106 >>
# Completed frame: 106
# -------------------------
# << finding stats for : 107 >>
# << finding params for: 107 >>
# << finding quality for: 107 >>
# Completed frame: 107
# -------------------------
# << finding stats for : 108 >>
# << finding params for: 108 >>
# << finding quality for: 108 >>
# Completed frame: 108
# -------------------------
# << finding stats for : 109 >>
# << finding params for: 109 >>
# << finding quality for: 109 >>
# Completed frame: 109
# -------------------------
# << finding stats for : 110 >>
# << finding params for: 110 >>
# << finding quality for: 110 >>
# Completed frame: 110
# -------------------------
# << finding stats for : 111 >>
# << finding params for: 111 >>
# << finding quality for: 111 >>
# Completed frame: 111
# -------------------------
# << finding stats for : 112 >>
# << finding params for: 112 >>
# << finding quality for: 112 >>
# Completed frame: 112
# -------------------------
# << finding stats for : 113 >>
# << finding params for: 113 >>
# << finding quality for: 113 >>
# Completed frame: 113
# -------------------------
# << finding stats for : 114 >>
# << finding params for: 114 >>
# << finding quality for: 114 >>
# Completed frame: 114
# -------------------------
# << finding stats for : 115 >>
# << finding params for: 115 >>
# << finding quality for: 115 >>
# Completed frame: 115
# -------------------------
# << finding stats for : 116 >>
# << finding params for: 116 >>
# << finding quality for: 116 >>
# Completed frame: 116
# -------------------------
# << finding stats for : 117 >>
# << finding params for: 117 >>
# << finding quality for: 117 >>
# Completed frame: 117
# -------------------------
# << finding stats for : 118 >>
# << finding params for: 118 >>
# << finding quality for: 118 >>
# Completed frame: 118
# -------------------------
# << finding stats for : 119 >>
# << finding params for: 119 >>
# << finding quality for: 119 >>
# <<<<<----- Joining complete ----->>>>>
# <<<<<----- Joining images ----->>>>>
# Completed frame: 119
# -------------------------
# << finding stats for : 120 >>
# << finding params for: 120 >>
# << finding quality for: 120 >>
# Completed frame: 120
# -------------------------
# << finding stats for : 121 >>
# << finding params for: 121 >>
# << finding quality for: 121 >>
# Completed frame: 121
# -------------------------
# << finding stats for : 122 >>
# << finding params for: 122 >>
# << finding quality for: 122 >>
# Completed frame: 122
# -------------------------
# << finding stats for : 123 >>
# << finding params for: 123 >>
# << finding quality for: 123 >>
# Completed frame: 123
# -------------------------
# << finding stats for : 124 >>
# << finding params for: 124 >>
# << finding quality for: 124 >>
# Completed frame: 124
# -------------------------
# << finding stats for : 125 >>
# << finding params for: 125 >>
# << finding quality for: 125 >>
# Completed frame: 125
# -------------------------
# << finding stats for : 126 >>
# << finding params for: 126 >>
# << finding quality for: 126 >>
# Completed frame: 126
# -------------------------
# << finding stats for : 127 >>
# << finding params for: 127 >>
# << finding quality for: 127 >>
# Completed frame: 127
# -------------------------
# << finding stats for : 128 >>
# << finding params for: 128 >>
# << finding quality for: 128 >>
# Completed frame: 128
# -------------------------
# << finding stats for : 129 >>
# << finding params for: 129 >>
# << finding quality for: 129 >>
# Completed frame: 129
# -------------------------
# << finding stats for : 130 >>
# << finding params for: 130 >>
# << finding quality for: 130 >>
# Completed frame: 130
# -------------------------
# << finding stats for : 131 >>
# << finding params for: 131 >>
# << finding quality for: 131 >>
# Completed frame: 131
# -------------------------
# << finding stats for : 132 >>
# << finding params for: 132 >>
# << finding quality for: 132 >>
# Completed frame: 132
# -------------------------
# << finding stats for : 133 >>
# << finding params for: 133 >>
# << finding quality for: 133 >>
# Completed frame: 133
# -------------------------
# << finding stats for : 134 >>
# << finding params for: 134 >>
# << finding quality for: 134 >>
# <<<<<----- Joining complete ----->>>>>
# <<<<<----- Joining images ----->>>>>
# Completed frame: 134
# -------------------------
# << finding stats for : 135 >>
# << finding params for: 135 >>
# << finding quality for: 135 >>
# Completed frame: 135
# -------------------------
# << finding stats for : 136 >>
# << finding params for: 136 >>
# << finding quality for: 136 >>
# Completed frame: 136
# -------------------------
# << finding stats for : 137 >>
# << finding params for: 137 >>
# << finding quality for: 137 >>
# Completed frame: 137
# -------------------------
# << finding stats for : 138 >>
# << finding params for: 138 >>
# << finding quality for: 138 >>
# Completed frame: 138
# -------------------------
# << finding stats for : 139 >>
# << finding params for: 139 >>
# << finding quality for: 139 >>
# Completed frame: 139
# -------------------------
# << finding stats for : 140 >>
# << finding params for: 140 >>
# << finding quality for: 140 >>
# Completed frame: 140
# -------------------------
# << finding stats for : 141 >>
# << finding params for: 141 >>
# << finding quality for: 141 >>
# Completed frame: 141
# -------------------------
# << finding stats for : 142 >>
# << finding params for: 142 >>
# << finding quality for: 142 >>
# Completed frame: 142
# -------------------------
# << finding stats for : 143 >>
# << finding params for: 143 >>
# << finding quality for: 143 >>
# Completed frame: 143
# -------------------------
# << finding stats for : 144 >>
# << finding params for: 144 >>
# << finding quality for: 144 >>
# Completed frame: 144
# -------------------------
# << finding stats for : 145 >>
# << finding params for: 145 >>
# << finding quality for: 145 >>
# Completed frame: 145
# -------------------------
# << finding stats for : 146 >>
# << finding params for: 146 >>
# << finding quality for: 146 >>
# Completed frame: 146
# -------------------------
# << finding stats for : 147 >>
# << finding params for: 147 >>
# << finding quality for: 147 >>
# Completed frame: 147
# -------------------------
# << finding stats for : 148 >>
# << finding params for: 148 >>
# << finding quality for: 148 >>
# Completed frame: 148
# -------------------------
# << finding stats for : 149 >>
# << finding params for: 149 >>
# << finding quality for: 149 >>
# Completed frame: 149
# -------------------------
# << finding stats for : 150 >>
# << finding params for: 150 >>
# << finding quality for: 150 >>
# Completed frame: 150
# -------------------------
# << finding stats for : 151 >>
# << finding params for: 151 >>
# << finding quality for: 151 >>
# Completed frame: 151
# -------------------------
# << finding stats for : 152 >>
# << finding params for: 152 >>
# << finding quality for: 152 >>
# Completed frame: 152
# -------------------------
# << finding stats for : 153 >>
# << finding params for: 153 >>
# << finding quality for: 153 >>
# Completed frame: 153
# -------------------------
# << finding stats for : 154 >>
# << finding params for: 154 >>
# << finding quality for: 154 >>
# Completed frame: 154
# -------------------------
# << finding stats for : 155 >>
# << finding params for: 155 >>
# << finding quality for: 155 >>
# Completed frame: 155
# -------------------------
# << finding stats for : 156 >>
# << finding params for: 156 >>
# << finding quality for: 156 >>
# Completed frame: 156
# -------------------------
# << finding stats for : 157 >>
# << finding params for: 157 >>
# << finding quality for: 157 >>
# Completed frame: 157
# -------------------------
# << finding stats for : 158 >>
# << finding params for: 158 >>
# << finding quality for: 158 >>
# Completed frame: 158
# -------------------------
# << finding stats for : 159 >>
# << finding params for: 159 >>
# << finding quality for: 159 >>
# Completed frame: 159
# -------------------------
# << finding stats for : 160 >>
# << finding params for: 160 >>
# << finding quality for: 160 >>
# Completed frame: 160
# -------------------------
# << finding stats for : 161 >>
# << finding params for: 161 >>
# << finding quality for: 161 >>
# Completed frame: 161
# -------------------------
# << finding stats for : 162 >>
# << finding params for: 162 >>
# << finding quality for: 162 >>
# Completed frame: 162
# -------------------------
# << finding stats for : 163 >>
# << finding params for: 163 >>
# << finding quality for: 163 >>
# Completed frame: 163
# -------------------------
# << finding stats for : 164 >>
# << finding params for: 164 >>
# << finding quality for: 164 >>
# Completed frame: 164
# -------------------------
# << finding stats for : 165 >>
# << finding params for: 165 >>
# << finding quality for: 165 >>
# Completed frame: 165
# -------------------------
# << finding stats for : 166 >>
# << finding params for: 166 >>
# << finding quality for: 166 >>
# Completed frame: 166
# -------------------------
# << finding stats for : 167 >>
# << finding params for: 167 >>
# << finding quality for: 167 >>
# Completed frame: 167
# -------------------------
# << finding stats for : 168 >>
# << finding params for: 168 >>
# << finding quality for: 168 >>
# Completed frame: 168
# -------------------------
# << finding stats for : 169 >>
# << finding params for: 169 >>
# << finding quality for: 169 >>
# Completed frame: 169
# -------------------------
# << finding stats for : 170 >>
# << finding params for: 170 >>
# << finding quality for: 170 >>
# Completed frame: 170
# -------------------------
# << finding stats for : 171 >>
# << finding params for: 171 >>
# << finding quality for: 171 >>
# Completed frame: 171
# -------------------------
# << finding stats for : 172 >>
# << finding params for: 172 >>
# << finding quality for: 172 >>
# Completed frame: 172
# -------------------------
# << finding stats for : 173 >>
# << finding params for: 173 >>
# << finding quality for: 173 >>
# Completed frame: 173
# -------------------------
# << finding stats for : 174 >>
# << finding params for: 174 >>
# << finding quality for: 174 >>
# Completed frame: 174
# -------------------------
# << finding stats for : 175 >>
# << finding params for: 175 >>
# << finding quality for: 175 >>
# <<<<<----- Joining complete ----->>>>>
# Completed frame: 175
# -------------------------
# << finding stats for : 176 >>
# << finding params for: 176 >>
# << finding quality for: 176 >>
# <<<<<----- Joining images ----->>>>>
# Completed frame: 176
# -------------------------
# << finding stats for : 177 >>
# << finding params for: 177 >>
# << finding quality for: 177 >>
# Completed frame: 177
# -------------------------
# << finding stats for : 178 >>
# << finding params for: 178 >>
# << finding quality for: 178 >>
# Completed frame: 178
# -------------------------
# << finding stats for : 179 >>
# << finding params for: 179 >>
# << finding quality for: 179 >>
# Completed frame: 179
# -------------------------
# << finding stats for : 180 >>
# << finding params for: 180 >>
# << finding quality for: 180 >>
# Completed frame: 180
# -------------------------
# << finding stats for : 181 >>
# << finding params for: 181 >>
# << finding quality for: 181 >>
# Completed frame: 181
# -------------------------
# << finding stats for : 182 >>
# << finding params for: 182 >>
# << finding quality for: 182 >>
# Completed frame: 182
# -------------------------
# << finding stats for : 183 >>
# << finding params for: 183 >>
# << finding quality for: 183 >>
# Completed frame: 183
# -------------------------
# << finding stats for : 184 >>
# << finding params for: 184 >>
# << finding quality for: 184 >>
# Completed frame: 184
# -------------------------
# << finding stats for : 185 >>
# << finding params for: 185 >>
# << finding quality for: 185 >>
# Completed frame: 185
# -------------------------
# << finding stats for : 186 >>
# << finding params for: 186 >>
# << finding quality for: 186 >>
# Completed frame: 186
# -------------------------
# << finding stats for : 187 >>
# << finding params for: 187 >>
# << finding quality for: 187 >>
# Completed frame: 187
# -------------------------
# << finding stats for : 188 >>
# << finding params for: 188 >>
# << finding quality for: 188 >>
# Completed frame: 188
# -------------------------
# << finding stats for : 189 >>
# << finding params for: 189 >>
# << finding quality for: 189 >>
# Completed frame: 189
# -------------------------
# << finding stats for : 190 >>
# << finding params for: 190 >>
# << finding quality for: 190 >>
# Completed frame: 190
# -------------------------
# << finding stats for : 191 >>
# << finding params for: 191 >>
# << finding quality for: 191 >>
# Completed frame: 191
# -------------------------
# << finding stats for : 192 >>
# << finding params for: 192 >>
# << finding quality for: 192 >>
# Completed frame: 192
# -------------------------
# << finding stats for : 193 >>
# << finding params for: 193 >>
# << finding quality for: 193 >>
# Completed frame: 193
# -------------------------
# << finding stats for : 194 >>
# << finding params for: 194 >>
# << finding quality for: 194 >>
# Completed frame: 194
# -------------------------
# << finding stats for : 195 >>
# << finding params for: 195 >>
# << finding quality for: 195 >>
# Completed frame: 195
# -------------------------
# << finding stats for : 196 >>
# << finding params for: 196 >>
# << finding quality for: 196 >>
# Completed frame: 196
# -------------------------
# << finding stats for : 197 >>
# << finding params for: 197 >>
# << finding quality for: 197 >>
# Completed frame: 197
# -------------------------
# << finding stats for : 198 >>
# << finding params for: 198 >>
# << finding quality for: 198 >>
# Completed frame: 198
# -------------------------
# << finding stats for : 199 >>
# << finding params for: 199 >>
# << finding quality for: 199 >>
# Completed frame: 199
# -------------------------
# << finding stats for : 200 >>
# << finding params for: 200 >>
# << finding quality for: 200 >>
# Completed frame: 200
# -------------------------
# << finding stats for : 201 >>
# << finding params for: 201 >>
# << finding quality for: 201 >>
# Completed frame: 201
# -------------------------
# << finding stats for : 202 >>
# << finding params for: 202 >>
# << finding quality for: 202 >>
# Completed frame: 202
# -------------------------
# << finding stats for : 203 >>
# << finding params for: 203 >>
# << finding quality for: 203 >>
# Completed frame: 203
# -------------------------
# << finding stats for : 204 >>
# << finding params for: 204 >>
# << finding quality for: 204 >>
# Completed frame: 204
# -------------------------
# << finding stats for : 205 >>
# << finding params for: 205 >>
# << finding quality for: 205 >>
# Completed frame: 205
# -------------------------
# << finding stats for : 206 >>
# << finding params for: 206 >>
# << finding quality for: 206 >>
# Completed frame: 206
# -------------------------
# << finding stats for : 207 >>
# << finding params for: 207 >>
# << finding quality for: 207 >>
# Completed frame: 207
# -------------------------
# << finding stats for : 208 >>
# << finding params for: 208 >>
# << finding quality for: 208 >>
# Completed frame: 208
# -------------------------
# << finding stats for : 209 >>
# << finding params for: 209 >>
# << finding quality for: 209 >>
# Completed frame: 209
# -------------------------
# << finding stats for : 210 >>
# << finding params for: 210 >>
# << finding quality for: 210 >>
# Completed frame: 210
# -------------------------
# << finding stats for : 211 >>
# << finding params for: 211 >>
# << finding quality for: 211 >>
# Completed frame: 211
# -------------------------
# << finding stats for : 212 >>
# << finding params for: 212 >>
# << finding quality for: 212 >>
# Completed frame: 212
# -------------------------
# << finding stats for : 213 >>
# << finding params for: 213 >>
# << finding quality for: 213 >>
# Completed frame: 213
# -------------------------
# << finding stats for : 214 >>
# << finding params for: 214 >>
# << finding quality for: 214 >>
# Completed frame: 214
# -------------------------
# << finding stats for : 215 >>
# << finding params for: 215 >>
# << finding quality for: 215 >>
# Completed frame: 215
# -------------------------
# << finding stats for : 216 >>
# << finding params for: 216 >>
# << finding quality for: 216 >>
# Completed frame: 216
# -------------------------
# << finding stats for : 217 >>
# << finding params for: 217 >>
# << finding quality for: 217 >>
# Completed frame: 217
# -------------------------
# <<<<<----- Joining complete ----->>>>>
# << finding stats for : 218 >>
# << finding params for: 218 >>
# << finding quality for: 218 >>
# Completed frame: 218
# -------------------------
# << finding stats for : 219 >>
# << finding params for: 219 >>
# << finding quality for: 219 >>
# Completed frame: 219
# -------------------------
# << finding stats for : 220 >>
# << finding params for: 220 >>
# << finding quality for: 220 >>
# Completed frame: 220
# -------------------------
# << finding stats for : 221 >>
# << finding params for: 221 >>
# << finding quality for: 221 >>
# Completed frame: 221
# -------------------------
# << finding stats for : 222 >>
# << finding params for: 222 >>
# << finding quality for: 222 >>
# Completed frame: 222
# -------------------------
# << finding stats for : 223 >>
# << finding params for: 223 >>
# << finding quality for: 223 >>
# Completed frame: 223
# -------------------------
# << finding stats for : 224 >>
# << finding params for: 224 >>
# << finding quality for: 224 >>
# Completed frame: 224
# -------------------------
# << finding stats for : 225 >>
# << finding params for: 225 >>
# << finding quality for: 225 >>
# Completed frame: 225
# -------------------------
# << finding stats for : 226 >>
# << finding params for: 226 >>
# << finding quality for: 226 >>
# Completed frame: 226
# -------------------------
# << finding stats for : 227 >>
# << finding params for: 227 >>
# << finding quality for: 227 >>
# Completed frame: 227
# -------------------------
# << finding stats for : 228 >>
# << finding params for: 228 >>
# << finding quality for: 228 >>
# Completed frame: 228
# -------------------------
# << finding stats for : 229 >>
# << finding params for: 229 >>
# << finding quality for: 229 >>
# Completed frame: 229
# -------------------------
# << finding stats for : 230 >>
# << finding params for: 230 >>
# << finding quality for: 230 >>
# Completed frame: 230
# -------------------------
# << finding stats for : 231 >>
# << finding params for: 231 >>
# << finding quality for: 231 >>
# Completed frame: 231
# -------------------------
# << finding stats for : 232 >>
# << finding params for: 232 >>
# << finding quality for: 232 >>
# Completed frame: 232
# -------------------------
# << finding stats for : 233 >>
# << finding params for: 233 >>
# << finding quality for: 233 >>
# <<<<<----- Joining images ----->>>>>
# Completed frame: 233
# -------------------------
# << finding stats for : 234 >>
# << finding params for: 234 >>
# << finding quality for: 234 >>
# Completed frame: 234
# -------------------------
# << finding stats for : 235 >>
# << finding params for: 235 >>
# << finding quality for: 235 >>
# Completed frame: 235
# -------------------------
# << finding stats for : 236 >>
# << finding params for: 236 >>
# << finding quality for: 236 >>
# Completed frame: 236
# -------------------------
# << finding stats for : 237 >>
# << finding params for: 237 >>
# << finding quality for: 237 >>
# Completed frame: 237
# -------------------------
# << finding stats for : 238 >>
# << finding params for: 238 >>
# << finding quality for: 238 >>
# Completed frame: 238
# -------------------------
# << finding stats for : 239 >>
# << finding params for: 239 >>
# << finding quality for: 239 >>
# Completed frame: 239
# -------------------------
# << finding stats for : 240 >>
# << finding params for: 240 >>
# << finding quality for: 240 >>
# Completed frame: 240
# -------------------------
# << finding stats for : 241 >>
# << finding params for: 241 >>
# << finding quality for: 241 >>
# Completed frame: 241
# -------------------------
# << finding stats for : 242 >>
# << finding params for: 242 >>
# << finding quality for: 242 >>
# Completed frame: 242
# -------------------------
# << finding stats for : 243 >>
# << finding params for: 243 >>
# << finding quality for: 243 >>
# Completed frame: 243
# -------------------------
# << finding stats for : 244 >>
# << finding params for: 244 >>
# << finding quality for: 244 >>
# Completed frame: 244
# -------------------------
# << finding stats for : 245 >>
# << finding params for: 245 >>
# << finding quality for: 245 >>
# Completed frame: 245
# -------------------------
# << finding stats for : 246 >>
# << finding params for: 246 >>
# << finding quality for: 246 >>
# Completed frame: 246
# -------------------------
# << finding stats for : 247 >>
# << finding params for: 247 >>
# << finding quality for: 247 >>
# Completed frame: 247
# -------------------------
# << finding stats for : 248 >>
# << finding params for: 248 >>
# << finding quality for: 248 >>
# Completed frame: 248
# -------------------------
# << finding stats for : 249 >>
# << finding params for: 249 >>
# << finding quality for: 249 >>
# Completed frame: 249
# -------------------------
# << finding stats for : 250 >>
# << finding params for: 250 >>
# << finding quality for: 250 >>
# Completed frame: 250
# -------------------------
# << finding stats for : 251 >>
# << finding params for: 251 >>
# << finding quality for: 251 >>
# Completed frame: 251
# -------------------------
# << finding stats for : 252 >>
# << finding params for: 252 >>
# << finding quality for: 252 >>
# Completed frame: 252
# -------------------------
# << finding stats for : 253 >>
# << finding params for: 253 >>
# << finding quality for: 253 >>
# Completed frame: 253
# -------------------------
# << finding stats for : 254 >>
# << finding params for: 254 >>
# << finding quality for: 254 >>
# Completed frame: 254
# -------------------------
# << finding stats for : 255 >>
# << finding params for: 255 >>
# << finding quality for: 255 >>
# Completed frame: 255
# -------------------------
# << finding stats for : 256 >>
# << finding params for: 256 >>
# << finding quality for: 256 >>
# Completed frame: 256
# -------------------------
# << finding stats for : 257 >>
# << finding params for: 257 >>
# << finding quality for: 257 >>
# Completed frame: 257
# -------------------------
# << finding stats for : 258 >>
# << finding params for: 258 >>
# << finding quality for: 258 >>
# Completed frame: 258
# -------------------------
# << finding stats for : 259 >>
# << finding params for: 259 >>
# << finding quality for: 259 >>
# Completed frame: 259
# -------------------------
# << finding stats for : 260 >>
# << finding params for: 260 >>
# << finding quality for: 260 >>
# Completed frame: 260
# -------------------------
# << finding stats for : 261 >>
# << finding params for: 261 >>
# << finding quality for: 261 >>
# Completed frame: 261
# -------------------------
# << finding stats for : 262 >>
# << finding params for: 262 >>
# << finding quality for: 262 >>
# Completed frame: 262
# -------------------------
# << finding stats for : 263 >>
# << finding params for: 263 >>
# << finding quality for: 263 >>
# Completed frame: 263
# -------------------------
# << finding stats for : 264 >>
# << finding params for: 264 >>
# << finding quality for: 264 >>
# Completed frame: 264
# -------------------------
# << finding stats for : 265 >>
# << finding params for: 265 >>
# << finding quality for: 265 >>
# Completed frame: 265
# -------------------------
# << finding stats for : 266 >>
# << finding params for: 266 >>
# << finding quality for: 266 >>
# Completed frame: 266
# -------------------------
# << finding stats for : 267 >>
# << finding params for: 267 >>
# << finding quality for: 267 >>
# Completed frame: 267
# -------------------------
# << finding stats for : 268 >>
# << finding params for: 268 >>
# << finding quality for: 268 >>
# Completed frame: 268
# -------------------------
# << finding stats for : 269 >>
# << finding params for: 269 >>
# << finding quality for: 269 >>
# Completed frame: 269
# -------------------------
# << finding stats for : 270 >>
# << finding params for: 270 >>
# << finding quality for: 270 >>
# Completed frame: 270
# -------------------------
# << finding stats for : 271 >>
# << finding params for: 271 >>
# << finding quality for: 271 >>
# Completed frame: 271
# -------------------------
# << finding stats for : 272 >>
# << finding params for: 272 >>
# << finding quality for: 272 >>
# Completed frame: 272
# -------------------------
# << finding stats for : 273 >>
# << finding params for: 273 >>
# << finding quality for: 273 >>
# Completed frame: 273
# -------------------------
# << finding stats for : 274 >>
# << finding params for: 274 >>
# << finding quality for: 274 >>
# <<<<<----- Joining complete ----->>>>>
# <<<<<----- Joining images ----->>>>>
# Completed frame: 274
# -------------------------
# << finding stats for : 275 >>
# << finding params for: 275 >>
# << finding quality for: 275 >>
# Completed frame: 275
# -------------------------
# << finding stats for : 276 >>
# << finding params for: 276 >>
# << finding quality for: 276 >>
# Completed frame: 276
# -------------------------
# << finding stats for : 277 >>
# << finding params for: 277 >>
# << finding quality for: 277 >>
# Completed frame: 277
# -------------------------
# << finding stats for : 278 >>
# << finding params for: 278 >>
# << finding quality for: 278 >>
# Completed frame: 278
# -------------------------
# << finding stats for : 279 >>
# << finding params for: 279 >>
# << finding quality for: 279 >>
# Completed frame: 279
# -------------------------
# << finding stats for : 280 >>
# << finding params for: 280 >>
# << finding quality for: 280 >>
# Completed frame: 280
# -------------------------
# << finding stats for : 281 >>
# << finding params for: 281 >>
# << finding quality for: 281 >>
# Completed frame: 281
# -------------------------
# << finding stats for : 282 >>
# << finding params for: 282 >>
# << finding quality for: 282 >>
# Completed frame: 282
# -------------------------
# << finding stats for : 283 >>
# << finding params for: 283 >>
# << finding quality for: 283 >>
# Completed frame: 283
# -------------------------
# << finding stats for : 284 >>
# << finding params for: 284 >>
# << finding quality for: 284 >>
# Completed frame: 284
# -------------------------
# << finding stats for : 285 >>
# << finding params for: 285 >>
# << finding quality for: 285 >>
# Completed frame: 285
# -------------------------
# << finding stats for : 286 >>
# << finding params for: 286 >>
# << finding quality for: 286 >>
# Completed frame: 286
# -------------------------
# << finding stats for : 287 >>
# << finding params for: 287 >>
# << finding quality for: 287 >>
# Completed frame: 287
# -------------------------
# << finding stats for : 288 >>
# << finding params for: 288 >>
# << finding quality for: 288 >>
# Completed frame: 288
# -------------------------
# << finding stats for : 289 >>
# << finding params for: 289 >>
# << finding quality for: 289 >>
# Completed frame: 289
# -------------------------
# << finding stats for : 290 >>
# << finding params for: 290 >>
# << finding quality for: 290 >>
# Completed frame: 290
# -------------------------
# << finding stats for : 291 >>
# << finding params for: 291 >>
# << finding quality for: 291 >>
# Completed frame: 291
# -------------------------
# << finding stats for : 292 >>
# << finding params for: 292 >>
# << finding quality for: 292 >>
# Completed frame: 292
# -------------------------
# << finding stats for : 293 >>
# << finding params for: 293 >>
# << finding quality for: 293 >>
# Completed frame: 293
# -------------------------
# << finding stats for : 294 >>
# << finding params for: 294 >>
# << finding quality for: 294 >>
# Completed frame: 294
# -------------------------
# << finding stats for : 295 >>
# << finding params for: 295 >>
# << finding quality for: 295 >>
# Completed frame: 295
# -------------------------
# << finding stats for : 296 >>
# << finding params for: 296 >>
# << finding quality for: 296 >>
# Completed frame: 296
# -------------------------
# << finding stats for : 297 >>
# << finding params for: 297 >>
# << finding quality for: 297 >>
# Completed frame: 297
# -------------------------
# << finding stats for : 298 >>
# << finding params for: 298 >>
# << finding quality for: 298 >>
# Completed frame: 298
# -------------------------
# << finding stats for : 299 >>
# << finding params for: 299 >>
# << finding quality for: 299 >>
# Completed frame: 299
# -------------------------
# << finding stats for : 300 >>
# << finding params for: 300 >>
# << finding quality for: 300 >>
# <<<<<----- Joining complete ----->>>>>
# <<<<<----- Joining images ----->>>>>
# Completed frame: 300
# -------------------------
# << finding stats for : 301 >>
# << finding params for: 301 >>
# << finding quality for: 301 >>
# Completed frame: 301
# -------------------------
# << finding stats for : 302 >>
# << finding params for: 302 >>
# << finding quality for: 302 >>
# Completed frame: 302
# -------------------------
# << finding stats for : 303 >>
# << finding params for: 303 >>
# << finding quality for: 303 >>
# Completed frame: 303
# -------------------------
# << finding stats for : 304 >>
# << finding params for: 304 >>
# << finding quality for: 304 >>
# Completed frame: 304
# -------------------------
# << finding stats for : 305 >>
# << finding params for: 305 >>
# << finding quality for: 305 >>
# Completed frame: 305
# -------------------------
# << finding stats for : 306 >>
# << finding params for: 306 >>
# << finding quality for: 306 >>
# Completed frame: 306
# -------------------------
# << finding stats for : 307 >>
# << finding params for: 307 >>
# << finding quality for: 307 >>
# Completed frame: 307
# -------------------------
# << finding stats for : 308 >>
# << finding params for: 308 >>
# << finding quality for: 308 >>
# Completed frame: 308
# -------------------------
# << finding stats for : 309 >>
# << finding params for: 309 >>
# << finding quality for: 309 >>
# Completed frame: 309
# -------------------------
# << finding stats for : 310 >>
# << finding params for: 310 >>
# << finding quality for: 310 >>
# Completed frame: 310
# -------------------------
# << finding stats for : 311 >>
# << finding params for: 311 >>
# << finding quality for: 311 >>
# Completed frame: 311
# -------------------------
# << finding stats for : 312 >>
# << finding params for: 312 >>
# << finding quality for: 312 >>
# Completed frame: 312
# -------------------------
# << finding stats for : 313 >>
# << finding params for: 313 >>
# << finding quality for: 313 >>
# Completed frame: 313
# -------------------------
# << finding stats for : 314 >>
# << finding params for: 314 >>
# << finding quality for: 314 >>
# Completed frame: 314
# -------------------------
# << finding stats for : 315 >>
# << finding params for: 315 >>
# << finding quality for: 315 >>
# Completed frame: 315
# -------------------------
# << finding stats for : 316 >>
# << finding params for: 316 >>
# << finding quality for: 316 >>
# Completed frame: 316
# -------------------------
# << finding stats for : 317 >>
# << finding params for: 317 >>
# << finding quality for: 317 >>
# Completed frame: 317
# -------------------------
# << finding stats for : 318 >>
# << finding params for: 318 >>
# << finding quality for: 318 >>
# Completed frame: 318
# -------------------------
# << finding stats for : 319 >>
# << finding params for: 319 >>
# << finding quality for: 319 >>
# Completed frame: 319
# -------------------------
# << finding stats for : 320 >>
# << finding params for: 320 >>
# << finding quality for: 320 >>
# Completed frame: 320
# -------------------------
# << finding stats for : 321 >>
# << finding params for: 321 >>
# << finding quality for: 321 >>
# Completed frame: 321
# -------------------------
# << finding stats for : 322 >>
# << finding params for: 322 >>
# << finding quality for: 322 >>
# Completed frame: 322
# -------------------------
# << finding stats for : 323 >>
# << finding params for: 323 >>
# << finding quality for: 323 >>
# Completed frame: 323
# -------------------------
# << finding stats for : 324 >>
# << finding params for: 324 >>
# << finding quality for: 324 >>
# Completed frame: 324
# -------------------------
# << finding stats for : 325 >>
# << finding params for: 325 >>
# << finding quality for: 325 >>
# Completed frame: 325
# -------------------------
# << finding stats for : 326 >>
# << finding params for: 326 >>
# << finding quality for: 326 >>
# Completed frame: 326
# -------------------------
# << finding stats for : 327 >>
# << finding params for: 327 >>
# << finding quality for: 327 >>
# Completed frame: 327
# -------------------------
# << finding stats for : 328 >>
# << finding params for: 328 >>
# << finding quality for: 328 >>
# Completed frame: 328
# -------------------------
# << finding stats for : 329 >>
# << finding params for: 329 >>
# << finding quality for: 329 >>
# Completed frame: 329
# -------------------------
# << finding stats for : 330 >>
# << finding params for: 330 >>
# << finding quality for: 330 >>
# Completed frame: 330
# -------------------------
# << finding stats for : 331 >>
# << finding params for: 331 >>
# << finding quality for: 331 >>
# Completed frame: 331
# -------------------------
# << finding stats for : 332 >>
# << finding params for: 332 >>
# << finding quality for: 332 >>
# Completed frame: 332
# -------------------------
# << finding stats for : 333 >>
# << finding params for: 333 >>
# << finding quality for: 333 >>
# Completed frame: 333
# -------------------------
# << finding stats for : 334 >>
# << finding params for: 334 >>
# << finding quality for: 334 >>
# Completed frame: 334
# -------------------------
# << finding stats for : 335 >>
# << finding params for: 335 >>
# << finding quality for: 335 >>
# Completed frame: 335
# -------------------------
# << finding stats for : 336 >>
# << finding params for: 336 >>
# << finding quality for: 336 >>
# Completed frame: 336
# -------------------------
# << finding stats for : 337 >>
# << finding params for: 337 >>
# << finding quality for: 337 >>
# Completed frame: 337
# -------------------------
# << finding stats for : 338 >>
# << finding params for: 338 >>
# << finding quality for: 338 >>
# Completed frame: 338
# -------------------------
# << finding stats for : 339 >>
# << finding params for: 339 >>
# << finding quality for: 339 >>
# Completed frame: 339
# -------------------------
# << finding stats for : 340 >>
# << finding params for: 340 >>
# << finding quality for: 340 >>
# Completed frame: 340
# -------------------------
# << finding stats for : 341 >>
# << finding params for: 341 >>
# << finding quality for: 341 >>
# Completed frame: 341
# -------------------------
# << finding stats for : 342 >>
# << finding params for: 342 >>
# << finding quality for: 342 >>
# Completed frame: 342
# -------------------------
# << finding stats for : 343 >>
# << finding params for: 343 >>
# << finding quality for: 343 >>
# Completed frame: 343
# -------------------------
# << finding stats for : 344 >>
# << finding params for: 344 >>
# << finding quality for: 344 >>
# Completed frame: 344
# -------------------------
# << finding stats for : 345 >>
# << finding params for: 345 >>
# << finding quality for: 345 >>
# Completed frame: 345
# -------------------------
# << finding stats for : 346 >>
# << finding params for: 346 >>
# << finding quality for: 346 >>
# Completed frame: 346
# -------------------------
# << finding stats for : 347 >>
# << finding params for: 347 >>
# << finding quality for: 347 >>
# Completed frame: 347
# -------------------------
# << finding stats for : 348 >>
# << finding params for: 348 >>
# << finding quality for: 348 >>
# Completed frame: 348
# -------------------------
# << finding stats for : 349 >>
# << finding params for: 349 >>
# << finding quality for: 349 >>
# Completed frame: 349
# -------------------------
# << finding stats for : 350 >>
# << finding params for: 350 >>
# << finding quality for: 350 >>
# Completed frame: 350
# -------------------------
# << finding stats for : 351 >>
# << finding params for: 351 >>
# << finding quality for: 351 >>
# Completed frame: 351
# -------------------------
# << finding stats for : 352 >>
# << finding params for: 352 >>
# << finding quality for: 352 >>
# Completed frame: 352
# -------------------------
# << finding stats for : 353 >>
# << finding params for: 353 >>
# << finding quality for: 353 >>
# Completed frame: 353
# -------------------------
# << finding stats for : 354 >>
# << finding params for: 354 >>
# << finding quality for: 354 >>
# Completed frame: 354
# -------------------------
# << finding stats for : 355 >>
# << finding params for: 355 >>
# << finding quality for: 355 >>
# Completed frame: 355
# -------------------------
# << finding stats for : 356 >>
# << finding params for: 356 >>
# << finding quality for: 356 >>
# Completed frame: 356
# -------------------------
# << finding stats for : 357 >>
# << finding params for: 357 >>
# << finding quality for: 357 >>
# Completed frame: 357
# -------------------------
# << finding stats for : 358 >>
# << finding params for: 358 >>
# << finding quality for: 358 >>
# Completed frame: 358
# -------------------------
# << finding stats for : 359 >>
# << finding params for: 359 >>
# << finding quality for: 359 >>
# Completed frame: 359
# -------------------------
# << finding stats for : 360 >>
# << finding params for: 360 >>
# << finding quality for: 360 >>
# Completed frame: 360
# -------------------------
# << finding stats for : 361 >>
# << finding params for: 361 >>
# << finding quality for: 361 >>
# Completed frame: 361
# -------------------------
# << finding stats for : 362 >>
# << finding params for: 362 >>
# << finding quality for: 362 >>
# Completed frame: 362
# -------------------------
# << finding stats for : 363 >>
# << finding params for: 363 >>
# << finding quality for: 363 >>
# KeyboardInterrupt

# %%
cv.imwrite("final_results/seven.jpg", res)
